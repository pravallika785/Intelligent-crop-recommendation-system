# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

df = pd.read_csv("Crop_recommendation.csv")

print(df.head())
print(df.shape)
print(df.info())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# (2200, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# ...

# %%
# Check for missing values
print("Missing values per column:")
print(df.isnull().sum())

# Check for duplicate rows
print("\nNumber of duplicate rows:", df.duplicated().sum())
# Out:
# Missing values per column:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64
#
# Number of duplicate rows: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,5))
sns.countplot(x='label', data=df)
plt.xticks(rotation=90)
plt.title("Distribution of Crops")
plt.xlabel("Crop")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
# Univariate analysis of numerical features
num_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

df[num_cols].hist(figsize=(12,8), bins=20)
plt.suptitle("Distribution of Numerical Features")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Nitrogen vs Crop
plt.figure(figsize=(12,5))
sns.boxplot(x='label', y='N', data=df)
plt.xticks(rotation=90)
plt.title("Nitrogen Levels Across Crops")
plt.show()

# Phosphorus vs Crop
plt.figure(figsize=(12,5))
sns.boxplot(x='label', y='P', data=df)
plt.xticks(rotation=90)
plt.title("Phosphorus Levels Across Crops")
plt.show()

# Potassium vs Crop
plt.figure(figsize=(12,5))
sns.boxplot(x='label', y='K', data=df)
plt.xticks(rotation=90)
plt.title("Potassium Levels Across Crops")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    df[['N','P','K','temperature','humidity','ph','rainfall']].corr(),
    annot=True,
    cmap='coolwarm'
)
plt.title("Correlation Matrix of Features")
plt.show()

# %% [markdown]
# ## Conclusion
# The dataset is clean and well-balanced across crop classes. Exploratory analysis reveals that soil nutrients (N, P, K), pH, rainfall, temperature, and humidity vary significantly across crops. Correlation analysis shows minimal multicollinearity among features, making the dataset suitable for machine learning models. These insights guide feature selection and model development in the ML phase.

# %% [markdown]
# The dataset is clean and well-balanced across crop classes. Exploratory analysis reveals that soil nutrients (N, P, K), pH, rainfall, temperature, and humidity vary significantly across crops. Correlation analysis shows minimal multicollinearity among features, making the dataset suitable for machine learning models. These insights guide feature selection and model development in the ML phase.
